# %%
# !pip install --upgrade google-genai
# !gcloud auth application-default login

# %%
from google import genai
from google.genai import types
import base64

def generate():
  client = genai.Client(
      vertexai=True,
      project="qwiklabs-gcp-04-0e4426b94a83",
      location="us-east1",
  )

  msg1_image1 = types.Part.from_uri(
      file_uri="gs://qwiklabs-gcp-04-0e4426b94a83-labconfig-bucket/cymbal-product-image.png",
      mime_type="image/png",
  )
  msg2_text1 = types.Part.from_text(text="""A vibrant hiking scene unfolds with a dirt path winding through a lush, green landscape adorned with wildflowers in a riot of colors. Yellow daffodils and bursts of blue and red blossoms paint a picturesque scene. A blue backpack sits amidst the greenery, a light blue water bottle tucked into its side pocket. Beside it lies a spread-out map, suggesting a moment of contemplation and navigation. The soft sunlight filters through the scene, enhancing the vividness of the colors and creating a tranquil, adventurous atmosphere.""")
  msg4_text1 = types.Part.from_text(text="""Here are some catchy phrases suitable for advertisements, inspired by the image:

**Focusing on Adventure & Exploration:**

*   **Wildflowers and Wanderlust: Your Adventure Awaits.**
*   **Uncharted Beauty: Discover Your Path.**
*   **Pack Your Dreams: The Trail is Calling.**
*   **Where Every Step is a Revelation.**
*   **Explore, Discover, Thrive.**

**Focusing on Relaxation & Escape:**

*   **Find Your Serenity on the Summit.**
*   **Unplug and Unwind in Nature's Embrace.**
*   **Your Perfect Hiking Retreat.**
*   **Recharge Your Soul, One Trail at a Time.**
*   **The Ultimate Escape: Nature's Canvas.**

**Focusing on Gear/Backpack:**

*   **Gear Up, Go Wild.**
*   **Your Reliable Companion for Unforgettable Journeys.**
*   **Engineered for Adventure, Designed for Comfort.**
*   **Carry Your World, Comfortably.**
*   **The Perfect Backpack for Every Horizon.**

**Short & Sweet:**

*   **Nature Beckons.**
*   **Find Your Trail.**
*   **Adventure Ready.**
*   **Live Wild.**
*   **Explore More.**

**Bonus - More evocative phrases:**

*   **Where wildflowers bloom and trails lead to discovery.**
*   **Lost in nature, found in wonder.**
*   **The map is optional. The adventure is mandatory.**

When choosing, consider what product or service you're advertising! Good luck!""")
  msg6_text1 = types.Part.from_text(text="""Where the earth breathes green and the mountains whisper tales, a tapestry of wildflowers unfurls, painting the landscape with hues of sun-kissed gold, sapphire blue, and ruby fire. A winding path beckons, inviting you to trace its gentle curve towards boundless horizons.

Beneath the cerulean sky, time slows, and the rhythm of nature guides your steps. A trusty pack, a steadfast companion, holds the essentials for a journey into the heart of serenity. A map, a gateway to uncharted dreams, lies open, urging you to seek the unknown, to wander where the spirit soars.

This is where adventure blossoms. This is where memories are etched in the canvas of the wild. Come, lose yourself in the symphony of nature, and rediscover the song within your soul. Let the wilderness be your guide, and let every step be a verse in your own epic poem.""")
  msg8_text1 = types.Part.from_text(text="""Okay, here are some catchy phrases suitable for advertisements, inspired by the poetic description and the nature-focused campaign:

**Emphasizing the Poetic & Emotional Connection:**

*   **Answer the Call of the Wild Within.**
*   **Write Your Story in the Language of Nature.**
*   **Where Adventure Blooms and Souls Take Flight.**
*   **Unleash Your Inner Explorer. Nature Awaits.**
*   **Find Your Verse in the Wilderness.**
*   **Let Nature Be Your Guide, Adventure Your Poem.**

**Focusing on the Journey & Discovery:**

*   **Trace Your Dreams Across the Mountain's Canvas.**
*   **Discover the Uncharted Chapters of Your Soul.**
*   **Every Step a Story, Every View a Memory.**
*   **Wander Where the Spirit Soars.**
*   **Beyond the Map Lies Your Greatest Adventure.**

**Highlighting the Serenity & Escape:**

*   **Escape the Ordinary, Embrace the Extraordinary.**
*   **Find Your Peace in the Symphony of Nature.**
*   **Slow Down, Breathe Deep, Explore Wild.**
*   **Reconnect with Your Soul in the Heart of the Wild.**
*   **Your Sanctuary Awaits: The Wilderness Within.**

**Short & Evocative:**

*   **Wild Soul, Open Road.**
*   **Nature's Embrace.**
*   **Dream. Explore. Discover.**
*   **Find Your Wild.**
*   **The Call of the Wild.**

**Campaign-Specific Phrases:**

*   **(Campaign Name): Where Adventure Blossoms.**
*   **(Campaign Name): Your Journey Starts Here.**
*   **(Campaign Name): Embrace the Wild Within.**

When selecting, consider the specific product, service, or overall message of your nature-focused campaign. Good luck!""")

  model = "gemini-2.0-flash-001"
  contents = [
    types.Content(
      role="user",
      parts=[
        msg1_image1,
        types.Part.from_text(text="""Short, descriptive text inspired by the image""")
      ]
    ),
    types.Content(
      role="model",
      parts=[
        msg2_text1
      ]
    ),
    types.Content(
      role="user",
      parts=[
        types.Part.from_text(text="""Catchy phrases suitable for advertisements""")
      ]
    ),
    types.Content(
      role="model",
      parts=[
        msg4_text1
      ]
    ),
    types.Content(
      role="user",
      parts=[
        types.Part.from_text(text="""A poetic description for a nature-focused campaign""")
      ]
    ),
    types.Content(
      role="model",
      parts=[
        msg6_text1
      ]
    ),
    types.Content(
      role="user",
      parts=[
        types.Part.from_text(text="""Catchy phrases suitable for advertisements""")
      ]
    ),
    types.Content(
      role="model",
      parts=[
        msg8_text1
      ]
    ),
    types.Content(
      role="user",
      parts=[
        # types.Part.from_text(text="""Describe this image with a focus on colors, textures, and the feeling it evokes in 10 words""")
        types.Part.from_text(text="""Create most creative unusual, and unexpected descriptions of the image you can think of """)
          
      ]
    ),
    
  ]
  generate_content_config = types.GenerateContentConfig(
    temperature = 0.5,
    top_p = 0.95,
    max_output_tokens = 1024,
    response_modalities = ["TEXT"],
    safety_settings = [types.SafetySetting(
      category="HARM_CATEGORY_HATE_SPEECH",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_DANGEROUS_CONTENT",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_SEXUALLY_EXPLICIT",
      threshold="OFF"
    ),types.SafetySetting(
      category="HARM_CATEGORY_HARASSMENT",
      threshold="OFF"
    )],
  )

  for chunk in client.models.generate_content_stream(
    model = model,
    contents = contents,
    config = generate_content_config,
    ):
    print(chunk.text, end="")

generate()
# Out:
# Okay, here are some creative, unusual, and unexpected descriptions of the image:
#
# **1. The Cartographer's Abandoned Daydream:**
#
# A cartographer, overwhelmed by the sheer, unmappable beauty of the place, simply gave up. His map lies discarded, a pale imitation of the vibrant reality. The backpack, a forgotten sentinel, stands guard over the surrendered dream of perfect representation, while nature laughs in a riot of untamed color.
#
# **2. The Backpack's Existential Crisis:**
#
# The backpack, usually a vessel of purpose, is experiencing a profound existential crisis. Surrounded by the untamed beauty of wildflowers and the open invitation of the path, it questions its own utility. "Am I merely a carrier of sustenance," it wonders, "or a barrier to the very experience I'm meant to enable?"
#
# **3. Nature's Guerrilla Marketing Campaign:**
#
# ...
